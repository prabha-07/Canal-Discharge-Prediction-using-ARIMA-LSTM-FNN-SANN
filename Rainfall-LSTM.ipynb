# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

import itertools
import warnings
warnings.filterwarnings('ignore')

# %%
filename = 'LSTM.csv'

# %%
rainfall_data_matrix = pd.read_csv(filename)
rainfall_data_matrix.set_index('YEAR', inplace=True)
rainfall_data_matrix = rainfall_data_matrix.transpose()
rainfall_data_matrix
# Out:
# YEAR   1951   1952    1953   1954   1955   1956   1957   1958    1959   1960  \
# Jan     6.6    5.2    13.1   23.5    4.2    7.9    1.2    4.4     3.0    9.4
# Feb     6.5   48.2    22.6    2.8    6.3   11.7   16.0   19.3    21.4    8.4
# Mar    41.6   20.8    18.5   90.6   28.2   15.1   25.7   57.3     6.3   44.4
# Apr   175.9  112.2   132.4  136.9  125.9  151.6   70.2  135.1   150.7  206.6
# May   148.5  214.6    55.4  179.5  544.2  351.3  381.2  353.5   347.2  540.0
# Jun   774.1  576.7   340.5  798.3  782.4  755.4  872.0  713.3   872.8  480.3
# Jul   544.6  430.0  1027.6  640.5  392.8  466.8  835.3  622.7  1155.7  750.9
# Aug   190.6  413.6   356.4  467.0  236.0  319.5  358.8  526.6   397.3  336.8
# Sep   313.8   57.4   100.5  201.6  438.5  178.4   41.3   86.1   405.5  371.2
# Oct   250.6  339.6   410.5  303.1  378.2  353.3  280.1  191.0   200.4  255.9
# Nov   229.6   49.6    62.2   31.6  178.1  178.2  192.5  206.1   151.9  358.0
# Dec    23.2   66.9     5.1   62.5   19.8    9.1   28.9    7.7    34.0   23.7
#
# YEAR  ...  2021  2022  2023  2024  2025  2026  2027  2028  2029  2030
# Jan   ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Feb   ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Mar   ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Apr   ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# May   ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Jun   ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Jul   ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Aug   ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Sep   ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Oct   ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Nov   ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Dec   ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [12 rows x 80 columns]

# %%
dates = pd.date_range(start='1951-01', freq='MS', periods=len(rainfall_data_matrix.columns)*12)
dates
# Out:
# DatetimeIndex(['1951-01-01', '1951-02-01', '1951-03-01', '1951-04-01',
#                '1951-05-01', '1951-06-01', '1951-07-01', '1951-08-01',
#                '1951-09-01', '1951-10-01',
#                ...
#                '2030-03-01', '2030-04-01', '2030-05-01', '2030-06-01',
#                '2030-07-01', '2030-08-01', '2030-09-01', '2030-10-01',
#                '2030-11-01', '2030-12-01'],
#               dtype='datetime64[ns]', length=960, freq='MS')

# %%
plt.figure(figsize=(13,7))
plt.plot(rainfall_data_matrix)
plt.xlabel('YEAR')
plt.ylabel('Rainfall')
plt.title('Month vs Precipitation across all years')
# Out:
# Text(0.5, 1.0, 'Month vs Precipitation across all years')

# %%
plt.figure(figsize=(15,7))
plt.boxplot(rainfall_data_matrix)
plt.xlabel('Month')
plt.ylabel('Rainfall')
plt.title('Month vs Precipitation across all years')
# Out:
# Text(0.5, 1.0, 'Month vs Precipitation across all years')

# %%
rainfall_data_matrix_np = rainfall_data_matrix.transpose().to_numpy()

shape = rainfall_data_matrix_np.shape
rainfall_data_matrix_np = rainfall_data_matrix_np.reshape((shape[0] * shape[1], 1))

# %%
rainfall_data = pd.DataFrame({'Precipitation': rainfall_data_matrix_np[:,0]})
rainfall_data.set_index(dates, inplace=True)

test_rainfall_data = rainfall_data.loc['2002':'2014']
rainfall_data = rainfall_data.loc[: '2001']
rainfall_data.head()
# Out:
#             Precipitation
# 1951-01-01            6.6
# 1951-02-01            6.5
# 1951-03-01           41.6
# 1951-04-01          175.9
# 1951-05-01          148.5

# %%
plt.figure(figsize=(20,5))
plt.plot(rainfall_data, color='blue')
plt.xlabel('Year')
plt.ylabel('Precipitation(mm)')
plt.title('Precipitation in mm')
# Out:
# Text(0.5, 1.0, 'Precipitation in mm')

# %%
scaler = MinMaxScaler(feature_range=(0, 1))

train_data = scaler.fit_transform(rainfall_data)
test_data = scaler.fit_transform(test_rainfall_data)

# %%
rainfall_data.head()
# Out:
#    Precipitation
# 0            6.6
# 1            6.5
# 2           41.6
# 3          175.9
# 4          148.5

# %%
train_data[:5]
# Out:
# array([[0.0050424 ],
#        [0.004966  ],
#        [0.03178241],
#        [0.13438765],
#        [0.11345405]])

# %%
scaler.inverse_transform(train_data[:5])
# Out:
# array([[  5.65569562],
#        [  5.57606387],
#        [ 33.52680877],
#        [140.47225151],
#        [118.6531515 ]])

# %%
print("Shape of train data: " + str(train_data.shape))
print("Shape of test data: " + str(test_data.shape))
# Out:
# Shape of train data: (612, 1)
# Shape of test data: (156, 1)

# %%
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []

    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    
    return np.array(dataX), np.array(dataY)

# %%
look_back = 12
trainX, trainY = create_dataset(train_data, look_back)
testX, testY = create_dataset(test_data, look_back)

# %%
testY
# Out:
# array([7.67533340e-04, 5.03693754e-02, 6.31296172e-02, 1.22517509e-01,
#        8.50043174e-02, 5.12520388e-01, 4.80859637e-01, 3.13441428e-01,
#        8.84582174e-02, 3.72541495e-01, 8.20301257e-02, 7.19562506e-03,
#        2.20665835e-03, 5.56461671e-03, 3.28120503e-02, 1.04480476e-01,
#        5.73251463e-01, 6.64875756e-01, 3.81655953e-01, 4.21087979e-01,
#        1.83824235e-01, 3.04518853e-01, 1.13307109e-01, 9.59416675e-04,
#        1.75573251e-02, 5.94838338e-03, 2.43691835e-02, 1.94281877e-01,
#        1.31344143e-01, 6.08749880e-01, 8.41120599e-01, 2.88784419e-01,
#        4.13412645e-01, 2.39950110e-01, 1.93418402e-01, 5.95797755e-02,
#        8.25098340e-03, 1.91883335e-04, 7.64655090e-02, 6.96536506e-02,
#        4.99664204e-01, 5.53295596e-01, 5.45908088e-01, 3.79929003e-01,
#        4.61287537e-01, 3.59205603e-01, 2.03971985e-01, 1.43912501e-03,
#        0.00000000e+00, 4.98896671e-03, 7.29156673e-03, 1.37196584e-01,
#        1.94089993e-01, 7.07090089e-01, 9.55291183e-01, 4.81723112e-01,
#        5.27487288e-01, 3.50858678e-01, 8.95135757e-02, 1.24724168e-02,
#        3.83766670e-04, 2.81109086e-02, 2.06850235e-01, 9.91077425e-02,
#        7.50263840e-02, 4.58217404e-01, 4.87671496e-01, 3.33301353e-01,
#        3.29559628e-01, 3.39345678e-01, 5.41111005e-02, 1.50628418e-02,
#        2.68636669e-03, 8.63475007e-04, 6.12107838e-02, 6.46646839e-02,
#        1.82289168e-01, 4.15619303e-01, 8.89475199e-01, 2.58946560e-01,
#        3.13921136e-01, 2.01189677e-01, 2.62688286e-01, 4.34615754e-02,
#        1.72695001e-02, 5.75650005e-04, 3.02216253e-02, 1.34222393e-01,
#        1.81713518e-01, 6.41561930e-01, 6.04048738e-01, 3.43375228e-01,
#        2.62304519e-01, 4.24158112e-01, 3.24858486e-01, 4.55722920e-02,
#        1.93802168e-02, 4.38453420e-02, 2.38894752e-02, 1.58111868e-01,
#        1.16281301e-01, 7.58035115e-01, 5.16166171e-01, 4.74815312e-01,
#        3.75611628e-01, 2.21145544e-01, 1.58687518e-01, 4.75870671e-02,
#        6.71591672e-03, 8.34692507e-03, 2.80149669e-02, 1.89101027e-01,
#        8.00153507e-02, 4.26172887e-01, 3.45581886e-01, 4.81819054e-01,
#        2.29876235e-01, 1.81233810e-01, 1.08414084e-01, 8.92257507e-03,
#        3.35795836e-03, 3.80888420e-02, 4.74911254e-02, 4.69154754e-02,
#        1.14074643e-01, 1.00000000e+00, 7.96123957e-01, 3.54312578e-01,
#        3.05286386e-01, 2.48968627e-01, 1.48229876e-01, 1.59263168e-02,
#        4.02955003e-03, 9.49822508e-03, 1.67897918e-02, 9.14324091e-02,
#        2.40429819e-01, 4.35575170e-01, 6.49908855e-01, 7.03732131e-01,
#        2.86289936e-01, 3.40688861e-01, 9.50781925e-02])

# %%
print("Shape of train input: " + str(trainX.shape))
print("Shape of train labels: " + str(trainY.shape))
print("Shape of test input: " + str(testX.shape))
print("Shape of test labels: " + str(testY.shape))
# Out:
# Shape of train input: (599, 12)
# Shape of train labels: (599,)
# Shape of test input: (143, 12)
# Shape of test labels: (143,)

# %%
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
print("Shape of train input: " + str(trainX.shape))
print("Shape of train labels: " + str(trainY.shape))
print("Shape of test input: " + str(testX.shape))
print("Shape of test labels: " + str(testY.shape))
# Out:
# Shape of train input: (599, 1, 12)
# Shape of train labels: (599,)
# Shape of test input: (143, 1, 12)
# Shape of test labels: (143,)

# %%
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
import pydot
import graphviz

def plot_keras_model(model, show_shapes=True, show_layer_names=True):
    return SVG(model_to_dot(model, show_shapes=show_shapes, show_layer_names=show_layer_names)   
   
plot_keras_model(model, show_shapes=True, show_layer_names=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\PALANI~1.L\AppData\Local\Temp/ipykernel_24072/1819038915.py in <module>
#       7     return SVG(model_to_dot(model, show_shapes=show_shapes, show_layer_names=show_layer_names, to_file='model_plot.png'))
#       8
# ----> 9 plot_keras_model(model, show_shapes=True, show_layer_names=False)
#
# C:\Users\PALANI~1.L\AppData\Local\Temp/ipykernel_24072/1819038915.py in plot_keras_model(model, show_shapes, show_layer_names)
#       5
#       6 def plot_keras_model(model, show_shapes=True, show_layer_names=True):
# ----> 7     return SVG(model_to_dot(model, show_shapes=show_shapes, show_layer_names=show_layer_names, to_file='model_plot.png'))
#       8
#       9 plot_keras_model(model, show_shapes=True, show_layer_names=False)
#
# TypeError: model_to_dot() got an unexpected keyword argument 'to_file'

# %%
model.fit(trainX, trainY, epochs=200, batch_size=1, verbose=2)
# Out:
# Epoch 1/200
# 599/599 - 5s - loss: 0.0189 - 5s/epoch - 8ms/step
# Epoch 2/200
# 599/599 - 1s - loss: 0.0124 - 1s/epoch - 2ms/step
# Epoch 3/200
# 599/599 - 1s - loss: 0.0111 - 1s/epoch - 2ms/step
# Epoch 4/200
# 599/599 - 2s - loss: 0.0105 - 2s/epoch - 3ms/step
# Epoch 5/200
# 599/599 - 2s - loss: 0.0103 - 2s/epoch - 3ms/step
# Epoch 6/200
# 599/599 - 1s - loss: 0.0102 - 1s/epoch - 2ms/step
# Epoch 7/200
# 599/599 - 1s - loss: 0.0101 - 1s/epoch - 2ms/step
# Epoch 8/200
# 599/599 - 1s - loss: 0.0100 - 1s/epoch - 2ms/step
# Epoch 9/200
# 599/599 - 1s - loss: 0.0099 - 1s/epoch - 2ms/step
# Epoch 10/200
# 599/599 - 1s - loss: 0.0098 - 1s/epoch - 2ms/step
# Epoch 11/200
# 599/599 - 1s - loss: 0.0099 - 1s/epoch - 2ms/step
# Epoch 12/200
# 599/599 - 1s - loss: 0.0098 - 1s/epoch - 2ms/step
# Epoch 13/200
# 599/599 - 1s - loss: 0.0096 - 1s/epoch - 2ms/step
# Epoch 14/200
# 599/599 - 1s - loss: 0.0096 - 1s/epoch - 2ms/step
# Epoch 15/200
# 599/599 - 2s - loss: 0.0095 - 2s/epoch - 3ms/step
# Epoch 16/200
# 599/599 - 2s - loss: 0.0095 - 2s/epoch - 3ms/step
# Epoch 17/200
# 599/599 - 1s - loss: 0.0095 - 1s/epoch - 2ms/step
# Epoch 18/200
# 599/599 - 1s - loss: 0.0093 - 1s/epoch - 2ms/step
# Epoch 19/200
# 599/599 - 1s - loss: 0.0092 - 1s/epoch - 2ms/step
# Epoch 20/200
# 599/599 - 2s - loss: 0.0093 - 2s/epoch - 3ms/step
# Epoch 21/200
# 599/599 - 2s - loss: 0.0093 - 2s/epoch - 3ms/step
# Epoch 22/200
# 599/599 - 2s - loss: 0.0092 - 2s/epoch - 3ms/step
# Epoch 23/200
# 599/599 - 2s - loss: 0.0092 - 2s/epoch - 3ms/step
# Epoch 24/200
# 599/599 - 1s - loss: 0.0092 - 1s/epoch - 2ms/step
# Epoch 25/200
# 599/599 - 1s - loss: 0.0092 - 1s/epoch - 2ms/step
# Epoch 26/200
# 599/599 - 2s - loss: 0.0091 - 2s/epoch - 3ms/step
# Epoch 27/200
# 599/599 - 2s - loss: 0.0090 - 2s/epoch - 3ms/step
# Epoch 28/200
# 599/599 - 2s - loss: 0.0089 - 2s/epoch - 3ms/step
# Epoch 29/200
# 599/599 - 1s - loss: 0.0090 - 1s/epoch - 2ms/step
# Epoch 30/200
# 599/599 - 2s - loss: 0.0090 - 2s/epoch - 3ms/step
# Epoch 31/200
# 599/599 - 1s - loss: 0.0089 - 1s/epoch - 2ms/step
# Epoch 32/200
# 599/599 - 1s - loss: 0.0089 - 1s/epoch - 2ms/step
# Epoch 33/200
# 599/599 - 2s - loss: 0.0089 - 2s/epoch - 3ms/step
# Epoch 34/200
# 599/599 - 2s - loss: 0.0089 - 2s/epoch - 3ms/step
# Epoch 35/200
# 599/599 - 1s - loss: 0.0089 - 1s/epoch - 2ms/step
# Epoch 36/200
# 599/599 - 1s - loss: 0.0088 - 1s/epoch - 2ms/step
# Epoch 37/200
# 599/599 - 2s - loss: 0.0088 - 2s/epoch - 3ms/step
# Epoch 38/200
# 599/599 - 2s - loss: 0.0087 - 2s/epoch - 3ms/step
# Epoch 39/200
# 599/599 - 1s - loss: 0.0087 - 1s/epoch - 2ms/step
# Epoch 40/200
# 599/599 - 1s - loss: 0.0089 - 1s/epoch - 2ms/step
# Epoch 41/200
# 599/599 - 1s - loss: 0.0088 - 1s/epoch - 2ms/step
# Epoch 42/200
# 599/599 - 1s - loss: 0.0088 - 1s/epoch - 2ms/step
# Epoch 43/200
# 599/599 - 1s - loss: 0.0087 - 1s/epoch - 2ms/step
# Epoch 44/200
# 599/599 - 1s - loss: 0.0087 - 1s/epoch - 2ms/step
# Epoch 45/200
# 599/599 - 1s - loss: 0.0087 - 1s/epoch - 2ms/step
# Epoch 46/200
# 599/599 - 1s - loss: 0.0088 - 1s/epoch - 2ms/step
# Epoch 47/200
# 599/599 - 1s - loss: 0.0087 - 1s/epoch - 2ms/step
# Epoch 48/200
# 599/599 - 1s - loss: 0.0087 - 1s/epoch - 2ms/step
# Epoch 49/200
# 599/599 - 2s - loss: 0.0087 - 2s/epoch - 3ms/step
# Epoch 50/200
# 599/599 - 2s - loss: 0.0086 - 2s/epoch - 3ms/step
# Epoch 51/200
# 599/599 - 1s - loss: 0.0086 - 1s/epoch - 2ms/step
# Epoch 52/200
# 599/599 - 1s - loss: 0.0086 - 1s/epoch - 2ms/step
# Epoch 53/200
# 599/599 - 1s - loss: 0.0085 - 1s/epoch - 2ms/step
# Epoch 54/200
# 599/599 - 1s - loss: 0.0086 - 1s/epoch - 2ms/step
# Epoch 55/200
# 599/599 - 1s - loss: 0.0087 - 1s/epoch - 2ms/step
# Epoch 56/200
# 599/599 - 1s - loss: 0.0085 - 1s/epoch - 2ms/step
# Epoch 57/200
# 599/599 - 1s - loss: 0.0086 - 1s/epoch - 2ms/step
# Epoch 58/200
# 599/599 - 2s - loss: 0.0085 - 2s/epoch - 3ms/step
# Epoch 59/200
# 599/599 - 2s - loss: 0.0085 - 2s/epoch - 3ms/step
# Epoch 60/200
# 599/599 - 2s - loss: 0.0085 - 2s/epoch - 3ms/step
# Epoch 61/200
# 599/599 - 2s - loss: 0.0085 - 2s/epoch - 3ms/step
# Epoch 62/200
# 599/599 - 2s - loss: 0.0085 - 2s/epoch - 3ms/step
# Epoch 63/200
# 599/599 - 1s - loss: 0.0085 - 1s/epoch - 2ms/step
# Epoch 64/200
# 599/599 - 1s - loss: 0.0085 - 1s/epoch - 2ms/step
# Epoch 65/200
# 599/599 - 1s - loss: 0.0085 - 1s/epoch - 2ms/step
# Epoch 66/200
# 599/599 - 1s - loss: 0.0085 - 1s/epoch - 2ms/step
# Epoch 67/200
# 599/599 - 1s - loss: 0.0084 - 1s/epoch - 2ms/step
# Epoch 68/200
# 599/599 - 1s - loss: 0.0084 - 1s/epoch - 2ms/step
# Epoch 69/200
# 599/599 - 1s - loss: 0.0084 - 1s/epoch - 2ms/step
# Epoch 70/200
# 599/599 - 1s - loss: 0.0085 - 1s/epoch - 2ms/step
# Epoch 71/200
# 599/599 - 2s - loss: 0.0084 - 2s/epoch - 3ms/step
# Epoch 72/200
# 599/599 - 2s - loss: 0.0084 - 2s/epoch - 3ms/step
# Epoch 73/200
# 599/599 - 1s - loss: 0.0084 - 1s/epoch - 2ms/step
# Epoch 74/200
# 599/599 - 1s - loss: 0.0084 - 1s/epoch - 2ms/step
# Epoch 75/200
# 599/599 - 1s - loss: 0.0085 - 1s/epoch - 2ms/step
# Epoch 76/200
# 599/599 - 1s - loss: 0.0084 - 1s/epoch - 2ms/step
# Epoch 77/200
# 599/599 - 1s - loss: 0.0084 - 1s/epoch - 2ms/step
# Epoch 78/200
# 599/599 - 1s - loss: 0.0082 - 1s/epoch - 2ms/step
# Epoch 79/200
# 599/599 - 1s - loss: 0.0083 - 1s/epoch - 2ms/step
# Epoch 80/200
# 599/599 - 1s - loss: 0.0085 - 1s/epoch - 2ms/step
# Epoch 81/200
# 599/599 - 1s - loss: 0.0083 - 1s/epoch - 2ms/step
# Epoch 82/200
# 599/599 - 2s - loss: 0.0082 - 2s/epoch - 3ms/step
# Epoch 83/200
# 599/599 - 2s - loss: 0.0083 - 2s/epoch - 3ms/step
# Epoch 84/200
# 599/599 - 1s - loss: 0.0083 - 1s/epoch - 2ms/step
# Epoch 85/200
# 599/599 - 1s - loss: 0.0082 - 1s/epoch - 2ms/step
# Epoch 86/200
# 599/599 - 1s - loss: 0.0083 - 1s/epoch - 2ms/step
# Epoch 87/200
# 599/599 - 1s - loss: 0.0083 - 1s/epoch - 2ms/step
# Epoch 88/200
# 599/599 - 1s - loss: 0.0083 - 1s/epoch - 2ms/step
# Epoch 89/200
# 599/599 - 1s - loss: 0.0082 - 1s/epoch - 2ms/step
# Epoch 90/200
# 599/599 - 1s - loss: 0.0082 - 1s/epoch - 2ms/step
# Epoch 91/200
# 599/599 - 2s - loss: 0.0082 - 2s/epoch - 3ms/step
# Epoch 92/200
# 599/599 - 1s - loss: 0.0083 - 1s/epoch - 2ms/step
# Epoch 93/200
# 599/599 - 1s - loss: 0.0081 - 1s/epoch - 2ms/step
# Epoch 94/200
# 599/599 - 2s - loss: 0.0082 - 2s/epoch - 3ms/step
# Epoch 95/200
# 599/599 - 2s - loss: 0.0081 - 2s/epoch - 3ms/step
# Epoch 96/200
# 599/599 - 1s - loss: 0.0082 - 1s/epoch - 2ms/step
# Epoch 97/200
# 599/599 - 1s - loss: 0.0082 - 1s/epoch - 2ms/step
# Epoch 98/200
# 599/599 - 1s - loss: 0.0082 - 1s/epoch - 2ms/step
# Epoch 99/200
# 599/599 - 1s - loss: 0.0081 - 1s/epoch - 2ms/step
# Epoch 100/200
# 599/599 - 1s - loss: 0.0082 - 1s/epoch - 2ms/step
# Epoch 101/200
# 599/599 - 2s - loss: 0.0082 - 2s/epoch - 3ms/step
# Epoch 102/200
# 599/599 - 1s - loss: 0.0082 - 1s/epoch - 2ms/step
# Epoch 103/200
# 599/599 - 1s - loss: 0.0081 - 1s/epoch - 2ms/step
# Epoch 104/200
# 599/599 - 1s - loss: 0.0082 - 1s/epoch - 2ms/step
# Epoch 105/200
# 599/599 - 1s - loss: 0.0081 - 1s/epoch - 2ms/step
# Epoch 106/200
# 599/599 - 2s - loss: 0.0081 - 2s/epoch - 3ms/step
# Epoch 107/200
# 599/599 - 1s - loss: 0.0080 - 1s/epoch - 2ms/step
# Epoch 108/200
# 599/599 - 1s - loss: 0.0081 - 1s/epoch - 2ms/step
# Epoch 109/200
# 599/599 - 1s - loss: 0.0080 - 1s/epoch - 2ms/step
# Epoch 110/200
# 599/599 - 1s - loss: 0.0080 - 1s/epoch - 2ms/step
# Epoch 111/200
# 599/599 - 1s - loss: 0.0081 - 1s/epoch - 2ms/step
# Epoch 112/200
# 599/599 - 1s - loss: 0.0080 - 1s/epoch - 2ms/step
# Epoch 113/200
# 599/599 - 1s - loss: 0.0081 - 1s/epoch - 2ms/step
# Epoch 114/200
# 599/599 - 1s - loss: 0.0081 - 1s/epoch - 2ms/step
# Epoch 115/200
# 599/599 - 1s - loss: 0.0080 - 1s/epoch - 2ms/step
# Epoch 116/200
# 599/599 - 1s - loss: 0.0080 - 1s/epoch - 2ms/step
# Epoch 117/200
# 599/599 - 2s - loss: 0.0079 - 2s/epoch - 3ms/step
# Epoch 118/200
# 599/599 - 2s - loss: 0.0080 - 2s/epoch - 3ms/step
# Epoch 119/200
# 599/599 - 1s - loss: 0.0079 - 1s/epoch - 2ms/step
# Epoch 120/200
# 599/599 - 1s - loss: 0.0080 - 1s/epoch - 2ms/step
# Epoch 121/200
# 599/599 - 1s - loss: 0.0080 - 1s/epoch - 2ms/step
# Epoch 122/200
# 599/599 - 1s - loss: 0.0080 - 1s/epoch - 2ms/step
# Epoch 123/200
# 599/599 - 2s - loss: 0.0079 - 2s/epoch - 3ms/step
# Epoch 124/200
# 599/599 - 1s - loss: 0.0079 - 1s/epoch - 2ms/step
# Epoch 125/200
# 599/599 - 1s - loss: 0.0079 - 1s/epoch - 2ms/step
# Epoch 126/200
# 599/599 - 1s - loss: 0.0079 - 1s/epoch - 2ms/step
# Epoch 127/200
# 599/599 - 1s - loss: 0.0079 - 1s/epoch - 2ms/step
# Epoch 128/200
# 599/599 - 2s - loss: 0.0079 - 2s/epoch - 3ms/step
# Epoch 129/200
# 599/599 - 2s - loss: 0.0078 - 2s/epoch - 3ms/step
# Epoch 130/200
# 599/599 - 2s - loss: 0.0079 - 2s/epoch - 3ms/step
# Epoch 131/200
# 599/599 - 1s - loss: 0.0079 - 1s/epoch - 2ms/step
# Epoch 132/200
# 599/599 - 1s - loss: 0.0079 - 1s/epoch - 2ms/step
# Epoch 133/200
# 599/599 - 1s - loss: 0.0079 - 1s/epoch - 2ms/step
# Epoch 134/200
# 599/599 - 1s - loss: 0.0078 - 1s/epoch - 2ms/step
# Epoch 135/200
# 599/599 - 1s - loss: 0.0078 - 1s/epoch - 2ms/step
# Epoch 136/200
# 599/599 - 1s - loss: 0.0079 - 1s/epoch - 2ms/step
# Epoch 137/200
# 599/599 - 1s - loss: 0.0079 - 1s/epoch - 2ms/step
# Epoch 138/200
# 599/599 - 1s - loss: 0.0078 - 1s/epoch - 2ms/step
# Epoch 139/200
# 599/599 - 1s - loss: 0.0078 - 1s/epoch - 2ms/step
# Epoch 140/200
# 599/599 - 2s - loss: 0.0079 - 2s/epoch - 3ms/step
# Epoch 141/200
# 599/599 - 1s - loss: 0.0079 - 1s/epoch - 2ms/step
# Epoch 142/200
# 599/599 - 1s - loss: 0.0078 - 1s/epoch - 2ms/step
# Epoch 143/200
# 599/599 - 1s - loss: 0.0078 - 1s/epoch - 2ms/step
# Epoch 144/200
# 599/599 - 1s - loss: 0.0077 - 1s/epoch - 2ms/step
# Epoch 145/200
# 599/599 - 2s - loss: 0.0078 - 2s/epoch - 3ms/step
# Epoch 146/200
# 599/599 - 1s - loss: 0.0077 - 1s/epoch - 2ms/step
# Epoch 147/200
# 599/599 - 1s - loss: 0.0078 - 1s/epoch - 2ms/step
# Epoch 148/200
# 599/599 - 1s - loss: 0.0077 - 1s/epoch - 2ms/step
# Epoch 149/200
# 599/599 - 1s - loss: 0.0077 - 1s/epoch - 2ms/step
# Epoch 150/200
# 599/599 - 2s - loss: 0.0077 - 2s/epoch - 3ms/step
# Epoch 151/200
# 599/599 - 2s - loss: 0.0077 - 2s/epoch - 3ms/step
# Epoch 152/200
# 599/599 - 2s - loss: 0.0078 - 2s/epoch - 3ms/step
# Epoch 153/200
# 599/599 - 2s - loss: 0.0076 - 2s/epoch - 3ms/step
# Epoch 154/200
# 599/599 - 1s - loss: 0.0077 - 1s/epoch - 2ms/step
# Epoch 155/200
# 599/599 - 2s - loss: 0.0076 - 2s/epoch - 3ms/step
# Epoch 156/200
# 599/599 - 2s - loss: 0.0075 - 2s/epoch - 3ms/step
# Epoch 157/200
# 599/599 - 2s - loss: 0.0076 - 2s/epoch - 3ms/step
# Epoch 158/200
# 599/599 - 2s - loss: 0.0077 - 2s/epoch - 3ms/step
# Epoch 159/200
# 599/599 - 1s - loss: 0.0077 - 1s/epoch - 2ms/step
# Epoch 160/200
# 599/599 - 1s - loss: 0.0075 - 1s/epoch - 2ms/step
# Epoch 161/200
# 599/599 - 2s - loss: 0.0076 - 2s/epoch - 3ms/step
# Epoch 162/200
# 599/599 - 2s - loss: 0.0076 - 2s/epoch - 3ms/step
# Epoch 163/200
# 599/599 - 1s - loss: 0.0076 - 1s/epoch - 3ms/step
# Epoch 164/200
# 599/599 - 1s - loss: 0.0075 - 1s/epoch - 2ms/step
# Epoch 165/200
# 599/599 - 1s - loss: 0.0075 - 1s/epoch - 2ms/step
# Epoch 166/200
# 599/599 - 1s - loss: 0.0077 - 1s/epoch - 2ms/step
# Epoch 167/200
# 599/599 - 1s - loss: 0.0075 - 1s/epoch - 2ms/step
# Epoch 168/200
# 599/599 - 1s - loss: 0.0076 - 1s/epoch - 2ms/step
# Epoch 169/200
# 599/599 - 2s - loss: 0.0075 - 2s/epoch - 3ms/step
# Epoch 170/200
# 599/599 - 1s - loss: 0.0075 - 1s/epoch - 2ms/step
# Epoch 171/200
# 599/599 - 2s - loss: 0.0075 - 2s/epoch - 3ms/step
# Epoch 172/200
# 599/599 - 2s - loss: 0.0075 - 2s/epoch - 3ms/step
# Epoch 173/200
# 599/599 - 2s - loss: 0.0074 - 2s/epoch - 3ms/step
# Epoch 174/200
# 599/599 - 1s - loss: 0.0076 - 1s/epoch - 2ms/step
# Epoch 175/200
# 599/599 - 1s - loss: 0.0075 - 1s/epoch - 2ms/step
# Epoch 176/200
# 599/599 - 1s - loss: 0.0076 - 1s/epoch - 2ms/step
# Epoch 177/200
# 599/599 - 2s - loss: 0.0075 - 2s/epoch - 3ms/step
# Epoch 178/200
# 599/599 - 2s - loss: 0.0075 - 2s/epoch - 3ms/step
# Epoch 179/200
# 599/599 - 1s - loss: 0.0075 - 1s/epoch - 2ms/step
# Epoch 180/200
# 599/599 - 1s - loss: 0.0074 - 1s/epoch - 2ms/step
# Epoch 181/200
# 599/599 - 1s - loss: 0.0074 - 1s/epoch - 2ms/step
# Epoch 182/200
# 599/599 - 1s - loss: 0.0074 - 1s/epoch - 2ms/step
# Epoch 183/200
# 599/599 - 2s - loss: 0.0074 - 2s/epoch - 3ms/step
# Epoch 184/200
# 599/599 - 2s - loss: 0.0074 - 2s/epoch - 3ms/step
# Epoch 185/200
# 599/599 - 1s - loss: 0.0074 - 1s/epoch - 2ms/step
# Epoch 186/200
# 599/599 - 1s - loss: 0.0074 - 1s/epoch - 2ms/step
# Epoch 187/200
# 599/599 - 1s - loss: 0.0074 - 1s/epoch - 2ms/step
# Epoch 188/200
# 599/599 - 1s - loss: 0.0073 - 1s/epoch - 2ms/step
# Epoch 189/200
# 599/599 - 1s - loss: 0.0072 - 1s/epoch - 2ms/step
# Epoch 190/200
# 599/599 - 1s - loss: 0.0075 - 1s/epoch - 2ms/step
# Epoch 191/200
# 599/599 - 1s - loss: 0.0073 - 1s/epoch - 2ms/step
# Epoch 192/200
# 599/599 - 1s - loss: 0.0074 - 1s/epoch - 2ms/step
# Epoch 193/200
# 599/599 - 1s - loss: 0.0074 - 1s/epoch - 2ms/step
# Epoch 194/200
# 599/599 - 1s - loss: 0.0073 - 1s/epoch - 2ms/step
# Epoch 195/200
# 599/599 - 2s - loss: 0.0074 - 2s/epoch - 3ms/step
# Epoch 196/200
# 599/599 - 2s - loss: 0.0074 - 2s/epoch - 3ms/step
# Epoch 197/200
# 599/599 - 1s - loss: 0.0072 - 1s/epoch - 2ms/step
# Epoch 198/200
# 599/599 - 1s - loss: 0.0073 - 1s/epoch - 2ms/step
# Epoch 199/200
# 599/599 - 1s - loss: 0.0073 - 1s/epoch - 2ms/step
# Epoch 200/200
# 599/599 - 1s - loss: 0.0073 - 1s/epoch - 2ms/step

# %%
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# %%
testY.shape
# Out:
# (143,)

# %%
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
# testPredictInTrain = scaler.inverse_transform(testPredictInTrain)
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# %%
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 87.73 RMSE
# Test Score: 143.86 RMSE

# %%
dates = pd.date_range(start='1951-01', freq='MS', periods=trainY.shape[1])

# %%
trainActual = pd.DataFrame({'Precipitation': trainY[0]})
trainActual.index = dates

trainPredictdf = pd.DataFrame({'Precipitation': trainPredict[:,0]})
trainPredictdf.index = dates

# %%
plt.figure(figsize=(20,5))
plt.plot(trainActual, color='blue', label='Actual values')
plt.plot(trainPredictdf, color='red', label='Predicted')
plt.title('Train data: Precipitation vs Year')
plt.xlabel('Year')
plt.ylabel('Monthly mean Precipitation')
plt.legend(loc='best')

# %%
testDates = pd.date_range(start='2002-01', freq='MS', periods=test_rainfall_data.shape[0]-12-1)

# %%
testActual = pd.DataFrame({'Precipitation': testY[0]})
testActual.index = testDates

testPredictdf = pd.DataFrame({'Precipitation': testPredict[:,0]})
testPredictdf.index = testDates

# %%
plt.figure(figsize=(10,5))
plt.plot(testActual, color='green', label='Actual future values')
plt.plot(testPredictdf, color='red', label='Forecast')
plt.title('Test data: Precipitation vs Year')
plt.xlabel('Year')
plt.ylabel('Monthly mean Precipitation')
plt.legend(loc='best')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\PALANI~1.L\AppData\Local\Temp/ipykernel_2556/1387327400.py in <module>
# ----> 1 test_rainfall_data.shape[0]
#
# NameError: name 'test_rainfall_data' is not defined

# %%
trainPredict = model.predict(trainX)
