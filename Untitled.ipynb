# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima_model import ARIMA
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Rainfall.csv', parse_dates = ['YEAR'], index_col = ['YEAR'])

# %%
df.head(65)
# Out:
#             ANNUAL  Unnamed: 2  Unnamed: 3  Unnamed: 4
# YEAR
# 1951-01-01  2705.6         NaN         NaN         NaN
# 1952-01-01  2334.8         NaN         NaN         NaN
# 1953-01-01  2544.8         NaN         NaN         NaN
# 1954-01-01  2937.9         NaN         NaN         NaN
# 1955-01-01  3134.6         NaN         NaN         NaN
# ...            ...         ...         ...         ...
# 2011-01-01  3041.6         NaN         NaN         NaN
# 2012-01-01  2187.6         NaN         NaN         NaN
# 2013-01-01  2823.7         NaN         NaN         NaN
# 2014-01-01  3046.4         NaN         NaN         NaN
# NaT            NaN         NaN         NaN         NaN
#
# [65 rows x 4 columns]

# %%
plt.xlabel('Date')
plt.ylabel('Forecast Rainfall')
plt.plot(df)

# %%
rolmean = df.rolling(window=0).mean()

rolstd = df.rolling(window=0).std()
print(rolmean, rolstd)
# Out:
#             ANNUAL  Unnamed: 2  Unnamed: 3  Unnamed: 4
# YEAR
# 1951-01-01     NaN         NaN         NaN         NaN
# 1952-01-01     NaN         NaN         NaN         NaN
# 1953-01-01     NaN         NaN         NaN         NaN
# 1954-01-01     NaN         NaN         NaN         NaN
# 1955-01-01     NaN         NaN         NaN         NaN
# ...            ...         ...         ...         ...
# NaT            NaN         NaN         NaN         NaN
# NaT            NaN         NaN         NaN         NaN
# NaT            NaN         NaN         NaN         NaN
# NaT            NaN         NaN         NaN         NaN
# NaT            NaN         NaN         NaN         NaN
#
# [80 rows x 4 columns]             ANNUAL  Unnamed: 2  Unnamed: 3  Unnamed: 4
# YEAR
# 1951-01-01     NaN         NaN         NaN         NaN
# 1952-01-01     NaN         NaN         NaN         NaN
# 1953-01-01     NaN         NaN         NaN         NaN
# ...

# %%
orig = plt.plot(df, color='blue' ,label='Original')
mean = plt.plot(rolmean, color='red' , label='Rolling Mean')
std = plt.plot(rolstd, color='black' , label='Rolling std')
plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviation')
plt.show(block=False)

# %%
from statsmodels.tsa.stattools import adfuller

print ('Results of Dicky-Fuller Test:')
dftest = adfuller(df['ANNUAL'], autolag='AIC')

dfoutput = pd.series(dftest[0:4], index=['Test Statistic', 'p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
    
print(dfoutput)
# Out:
# Results of Dicky-Fuller Test:
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# C:\Users\PALANI~1.L\AppData\Local\Temp/ipykernel_19784/1760960492.py in <module>
#       2
#       3 print ('Results of Dicky-Fuller Test:')
# ----> 4 dftest = adfuller(df['ANNUAL'], autolag='AIC')
#       5
#       6 dfoutput = pd.series(dftest[0:4], index=['Test Statistic', 'p-value','#Lags Used','Number of Observations Used'])
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py in adfuller(x, maxlag, regression, autolag, store, regresults)
#     312
#     313         if not regresults:
# --> 314             icbest, bestlag = _autolag(
#     315                 OLS, xdshort, fullRHS, startlag, maxlag, autolag
#     316             )
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py in _autolag(mod, endog, exog, startlag, maxlag, method, modargs, fitargs, regresults)
# ...

# %%
df_logScale = np.log(df)
plt.plot(df_logScale)

# %%
movingAverage = df_logScale.rolling(window=12).mean()
movingSTD = df_logScale.rolling(window=12).std()
plt.plot(df_logScale)
plt.plot(movingAverage, color='red')

# %%
dfLogScaleMinusMA = df_logScale - movingAverage
dfLogScaleMinusMA.head(65)
# Out:
#               ANNUAL  Unnamed: 2  Unnamed: 3  Unnamed: 4
# YEAR
# 1951-01-01       NaN         NaN         NaN         NaN
# 1952-01-01       NaN         NaN         NaN         NaN
# 1953-01-01       NaN         NaN         NaN         NaN
# 1954-01-01       NaN         NaN         NaN         NaN
# 1955-01-01       NaN         NaN         NaN         NaN
# ...              ...         ...         ...         ...
# 2011-01-01  0.063325         NaN         NaN         NaN
# 2012-01-01 -0.258099         NaN         NaN         NaN
# 2013-01-01 -0.000330         NaN         NaN         NaN
# 2014-01-01  0.057675         NaN         NaN         NaN
# NaT              NaN         NaN         NaN         NaN
#
# [65 rows x 4 columns]
